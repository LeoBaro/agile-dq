# %%
import pandas
from astropy.table import Table
import matplotlib.pyplot as plt

# %%
 # %matplotlib inline

# %%
filename = "../xmlgen/data/PKP068652_1_3201_000.lv1.cor.gz"

# %%
table = Table.read(filename, format="fits")
table = table.as_array()
print(f"Data lenght: {len(table)}")
# Out:
# Data lenght: 1368

# %%
columns = table.dtype.names
print(f"Columns: {len(columns)}")
# Out:
# Columns: 898

# %%
columns[0:10]
# Out:
# ('PAKTNUMB',
#  'PKTIDVNM',
#  'PKTIDTYP',
#  'PKTIDDFF',
#  'SEGMFLAG',
#  'PKTSEQCN',
#  'PKTLENGT',
#  '32BITSYN',
#  'CRCFLAG',
#  'MMPAGEID')

# %%
plt.plot(table["PKTSEQCN"])

# %%
data = plt.hist(table["PKTSEQCN"], bins=10)

# %%
len(data[0])
# Out:
# 100
